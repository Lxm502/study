# %% [markdown]
# 🧑‍💻 TensorFlow 每日学习打卡清单
# 📅 学习周期：6 周（30 天）
#
# Day 17
#
#  实现 波士顿房价预测（回归任务）
#
#  使用 MSE/MAPE 评估
#
# Day 18
#
#  学习正则化（L1/L2）
#
#  对比有无正则化的效果
#
# Day 19
#
#  学习优化器对比（SGD, Adam, RMSProp）
#
#  实验不同学习率的效果
#
# Day 20
#
#  综合练习：选择一个 Kaggle 数据集完成分类/回归任务
#
# ✅ 第 5 周：进阶学习
#
# Day 21
#
#  学习 Functional API 搭建多输入模型
#
#  小练习：一个文本输入 + 数字输入的模型
#
# Day 22
#
#  学习自定义层（继承 tf.keras.layers.Layer）
#
#  实现一个自定义激活函数层
#
# Day 23
#
#  学习自定义模型（继承 tf.keras.Model）
#
#  实现一个简单的残差网络（ResNet Block）
#
# Day 24
#
#  学习 Callbacks（LearningRateScheduler, ModelCheckpoint）
#
#  小练习：动态调整学习率
#
# Day 25
#
#  学习迁移学习（使用 MobileNetV2）
#
#  小练习：猫狗分类（Cats vs Dogs 数据集）
#
# ✅ 第 6 周：综合项目与部署
#
# Day 26
#
#  图像分类项目（CIFAR-10）
#
#  可视化训练结果
#
# Day 27
#
#  文本分类（IMDb 影评情感分析）
#
#  使用 Embedding 层
#
# Day 28
#
#  学习调参与优化（学习率、批大小、层数）
#
#  使用网格搜索或手动调参
#
# Day 29
#
#  学习模型部署（TensorFlow Serving / Flask API）
#
#  尝试在本地跑一个简单 API
#
# Day 30
#
#  项目总结：整理代码 + 笔记
#
#  发布到 GitHub / 写学习总结

# %% [markdown]
# # 📊 打卡总表
# | 天数     | 学习内容                | 完成情况   |
# | ------ | ------------------- | ------ |
# | Day 1  | 环境搭建 + Numpy 回顾     | - \[✔ ] |
# | Day 2  | 张量基础                | - \[✔ ] |
# | Day 3  | 数据类型与转换             | - \[ ] |
# | Day 4  | reshape 与索引         | - \[ ] |
# | Day 5  | 随机张量                | - \[ ] |
# | Day 6  | Dataset 基础          | - \[ ] |
# | Day 7  | map + prefetch      | - \[ ] |
# | Day 8  | GradientTape        | - \[ ] |
# | Day 9  | Sequential 模型       | - \[ ] |
# | Day 10 | model.compile + fit | - \[ ] |
# | Day 11 | evaluate + predict  | - \[ ] |
# | Day 12 | TensorBoard         | - \[ ] |
# | Day 13 | Dropout             | - \[ ] |
# | Day 14 | EarlyStopping       | - \[ ] |
# | Day 15 | 模型保存与加载             | - \[ ] |
# | Day 16 | MNIST 分类            | - \[ ] |
# | Day 17 | 房价预测                | - \[ ] |
# | Day 18 | 正则化                 | - \[ ] |
# | Day 19 | 优化器对比               | - \[ ] |
# | Day 20 | Kaggle 小项目          | - \[ ] |
# | Day 21 | Functional API      | - \[ ] |
# | Day 22 | 自定义层                | - \[ ] |
# | Day 23 | 自定义模型               | - \[ ] |
# | Day 24 | Callbacks           | - \[ ] |
# | Day 25 | 迁移学习                | - \[ ] |
# | Day 26 | CIFAR-10 分类         | - \[ ] |
# | Day 27 | IMDb 文本分类           | - \[ ] |
# | Day 28 | 调参与优化               | - \[ ] |
# | Day 29 | 模型部署                | - \[ ] |
# | Day 30 | 学习总结                | - \[ ] |

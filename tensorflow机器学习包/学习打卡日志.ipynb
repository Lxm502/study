# %% [markdown]
# # 模板

# %% [markdown]
# # 📅 学习日志 - Day X
#
# ## 🎯 今日目标
# - [ ] 目标 1
# - [ ] 目标 2
# - [ ] 目标 3
# - [ ] 目标 4
#
# ---
#
# ## 📖 学习内容
# 今天主要学习了：
# - xxx
# - xxx
# - xxx
#
# ---
#
# ## 🧑‍💻 代码记录
# ```python
# # 示例代码（可以贴核心代码，完整代码建议上传到 GitHub 并附链接）
# import tensorflow as tf
#
# x = tf.constant([[1.0, 2.0]])
# w = tf.Variable([[0.5], [0.2]])
# y = tf.matmul(x, w)
# print(y)

# %% [markdown]
# ---

# %%
# 📅 学习日志 - Day 6 2020-09-04

## 🎯 今日目标
- [ ] 目标 1 实现 波士顿房价预测（回归任务）[ ]
- [ ] 目标 2 使用 MSE/MAPE 评估
- [ ] 目标 3 扑克卡片分类模型的搭建
- [ ] 目标 4 绘制混淆矩阵
- [ ] 目标 5 实现昨天学习的内容



---

## 📖 学习内容
今天主要学习了：
- xxx 
- xxx 
- xxx

---

## 🧑‍💻 代码记录
```python
# 示例代码（可以贴核心代码，完整代码建议上传到 GitHub 并附链接）
import tensorflow as tf

x = tf.constant([[1.0, 2.0]])
w = tf.Variable([[0.5], [0.2]])
y = tf.matmul(x, w)
print(y)

# %% [markdown]
# # 📅 学习日志 - Day 5 2020-09-03
#
# ## 🎯 今日目标
# - [ ] 目标 1 实现 波士顿房价预测（回归任务）[ ]
# - [ ] 目标 2 使用 MSE/MAPE 评估
# - [ ] 目标 3 扑克卡片分类模型的搭建
# - [ ] 目标 4 绘制混淆矩阵
# - [ ] 目标 5 实现昨天学习的内容
#
#
#
# ---
#
# ## 📖 学习内容
# 今天主要学习了：
# - xxx
# - xxx
# - xxx
#
# ---
#
# ## 🧑‍💻 代码记录
# ```python
# # 示例代码（可以贴核心代码，完整代码建议上传到 GitHub 并附链接）
# import tensorflow as tf
#
# x = tf.constant([[1.0, 2.0]])
# w = tf.Variable([[0.5], [0.2]])
# y = tf.matmul(x, w)
# print(y)

# %%
# 📅 学习日志 - Day 4 2025-09-02

## 🎯 今日目标
- [✔ ] 目标 1  学习 TensorBoard 可视化训练曲线
- [✔ ] 目标 2  小练习：对 MNIST 训练过程画出 loss/accuracy
- [✔ ] 目标 3  学习过拟合与欠拟合概念
- [✔ ] 目标 4  使用 Dropout 防止过拟合
- [✔ ] 目标 5  学习 EarlyStopping callback
- [✔ ] 目标 6  对比有无 EarlyStopping 的训练过程
- [✔ ] 目标 7  学习 model.save
- [✔ ] 目标 8  tf.keras.models.load_model
- [ ] 目标 9  小练习：保存并加载模型
- [ ] 目标 10  
 
---

## 📖 学习内容
今天主要学习了：
- 学习 TensorBoard 可视化训练曲线
- xxx 
- xxx

---

## 🧑‍💻 代码记录
```python
# 示例代码（可以贴核心代码，完整代码建议上传到 GitHub 并附链接）
import tensorflow as tf

x = tf.constant([[1.0, 2.0]])
w = tf.Variable([[0.5], [0.2]])
y = tf.matmul(x, w)
print(y)

# %%
# 📅 学习日志 - Day 3 2025-08-31

## 🎯 今日目标
- [✔ ] 目标 1 学习 GradientTape 基本用法
- [✔ ] 目标 2 手动实现梯度下降
- [✔ ] 目标 3 使用 Sequential API 搭建全连接网络
- [✔ ] 目标 4 理解 Dense 层、激活函数（ReLU, Softmax）
- [✔ ] 目标 5 学习 model.compile(loss, optimizer, metrics)
- [✔ ] 目标 6 使用 model.fit() 训练一个简单模型
- [✔ ] 目标 7 学习 model.evaluate() 与 model.predict()
- [✔ ] 目标 8 熟悉 metrics（accuracy, precision, recall）

---

## 📖 学习内容
今天主要学习了：
- 学习 GradientTape 基本用法,只有在自定义的地方才需要使用，API调用不需要
- 
- 

---

## 🧑‍💻 代码记录
```python
# 示例代码（可以贴核心代码，完整代码建议上传到 GitHub 并附链接）
import tensorflow as tf

# %% [markdown]
# # 📅 学习日志 - Day 2 2025-08-30
#
# ## 🎯 今日目标
# - [✔ ] 目标 1  学习 tf.convert_to_tensor 创建张量 与 tf.cast 改变数据类型
# - [✔ ] 目标 2  理解数据类型（float32, int32 等）
# - [✔ ] 目标 3  掌握 tf.reshape 改变张量结构、tf.expand_dims 在、tf.squeeze
# - [✔ ] 目标 4  练习张量索引与切片
#
# ---
#
# ## 📖 学习内容
# 今天主要学习了：
# - tf.convert_to_tensor 创建张量，不复用张量
# - tf.cast 改变数据类型
# - tf.reshape 改变张量结构，不改变数据，
# - tf.expand_dims  在指定的维度增加 1 轴，像图片增加通道，为广播做准备
# - tf.squeeze 降维 去除张量中所有（或指定位置的）长度为 1 的维度
# - tf.math
# - tf.io
# - tf.data.dataset
#
# ---
#
# ## 🧑‍💻 代码记录
# ```python
# # 示例代码（可以贴核心代码，完整代码建议上传到 GitHub 并附链接）
# import
#
# x = tf.convert_to_tensor
# w =  tf.cast
# y =  tf.reshape
# print(y)

# %% [markdown]
# # 📅 学习日志 - Day 1 2025-08-29
#
# ## 🎯 今日目标
# - [✔ ] 目标 1 安装 TensorFlow 环境（pip / conda / Colab）
# - [✔ ] 目标 2 熟悉 Jupyter Notebook / Colab 使用方法
# - [✔ ] 目标 3 复习 Python Numpy 基础
# - [✔ ] 目标 4 学习 tf.constant()，tf.variable()，
#
# ---
#
# ## 📖 学习内容
# 今天主要学习了：
# - tf.constan()与tf.variable()。张量创建的方法，constan创建的张量是常量不能修改，只能用于超参数的创建，variable创建的张量是可修改的，通常用于表示模型的可训练参数，如神经网络的权重。
# - assign(value):张量原地修改、assign_add()张量原地加法、assign_sub()张量原地减法、
# - tf.GradientTape()  自动计算梯度-->需要`自定义训练循环`时使用
#
# ---
#
# ## 🧑‍💻 代码记录
# ```python
# # 示例代码（可以贴核心代码，完整代码建议上传到 GitHub 并附链接）
# import tensorflow as tf
#
# x = tf.constant([[1.0, 2.0]])
# w = tf.Variable([[0.5], [0.2]])
# y = tf.matmul(x, w) # 矩阵乘法
# print(y)

# %% [markdown]
# ---
